# %%
import numpy as np # numerical method에 대한 라이브러리, 수치해석 등 여러가지
import pandas as pd # dataframe을 쉽게 다룰 수 있게 해주는
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

plt.style.use('seaborn') # https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html
sns.set(font_scale=2.5)

import missingno as msno # dataset의 null data를 쉽게 보여줌

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline 
# matplolib의 그래프를 notebook에 바로 보여줌

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %% [markdown]
# ### 2. Exploratory data analysis

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21f" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21flevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21flevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21flevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21flevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_fc9bff6e_2ca6_11ea_afcb_00e0914fe21frow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()
